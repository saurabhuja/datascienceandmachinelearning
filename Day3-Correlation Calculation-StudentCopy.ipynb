# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

DF = pd.read_csv(r"DemographicData.csv")

DF.columns = (['CountryName', 'CountryCode', 'BirthRate', 'InternetAccess',
       'IncomeGroup'])

# %% [markdown]
# # Correlation Calculation between X & Y

# %%
mDict = {'X':[1,2,3,4,5],"y":[2,4,6,8,10]}
df = pd.DataFrame(mDict)

sns.lmplot(x="X",y="y", data=df)
plt.show()

# %%
df.X.corr(df.y)
# Out:
# 0.9999999999999999

# %%
mDict = {'X':[0,7,11,1,-5],"y":[-2,2000,-1000,-11,0]}
df = pd.DataFrame(mDict)

sns.lmplot(x="X",y="y", data=df)
plt.show()

# %%
df.X.corr(df.y)
# Out:
# 0.00821147220239583

# %% [markdown]
# #### Correlation Calculation between X as InternetAccess & y as BirthRate

# %%
DF.InternetAccess.corr(DF.BirthRate)    # corr() calculates & returns only pearson-r value
# Out:
# -0.8155885551284763

# %%
sns.lmplot(x="InternetAccess",y="BirthRate", data=DF)
plt.show()

# %%
sns.lmplot(x="InternetAccess",y="BirthRate", data=DF, fit_reg=False, hue="IncomeGroup")
plt.show()

# %% [markdown]
# # Correlation amongst X Feature using HeatMap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
dataset=pd.read_csv("HeatMapData.csv")
dataset
# Out:
#         age housing  deposits  withdrawal  purchases_partners  purchases  \
# 0      28.0       R         0           0                   1          0
# 1      35.0       R        47           2                  86         47
# 2      26.0       R        26           3                  38         25
# 3      32.0       R         5           3                 111          5
# 4      21.0      na         0           0                   4          0
# ...     ...     ...       ...         ...                 ...        ...
# 18960  29.0      na         1           1                   5          1
# 18961  28.0       R         0           0                  26          0
# 18962  24.0       R         0           0                   0          0
# 18963  46.0      na         2           0                  16          2
# 18964  34.0      na         0           0                   4          0
#
#        app_downloaded  web_user  app_web_user  ios_user  android_user  \
# 0                   1         1             1         1             0
# 1                   1         0             0         0             1
# 2                   1         0             0         0             1
# 3                   1         1             1         0             1
# 4                   1         0             0         0             1
# ...               ...       ...           ...       ...           ...
# 18960               1         0             0         0             1
# 18961               1         0             0         0             1
# 18962               1         1             1         0             1
# 18963               1         1             1         1             0
# 18964               1         0             0         1             1
#
#        registered_phones  payment_type
# 0                      0        Weekly
# 1                      2  Semi-Monthly
# 2                      0     Bi-Weekly
# 3                      0     Bi-Weekly
# 4                      0     Bi-Weekly
# ...                  ...           ...
# 18960                  0     Bi-Weekly
# 18961                  0       Monthly
# 18962                  2        Weekly
# 18963                  0  Semi-Monthly
# 18964                  2            na
#
# [18965 rows x 13 columns]

# %%
dataset.corr()
plt.rcParams['figure.figsize']=(10,8)
sns.heatmap(dataset.corr(),annot=True)
plt.show()
