# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read From CSV

# %%
custDF = pd.read_csv(r"D:\Hp-EDrive\Edrive\nData\customer.csv", header=None,
                    names=['CustId','FName','LName','Age','Job'])
custDF
# Out:
#        CustId     FName     LName  Age                         Job
# 0     4000001  Kristina     Chung   55                       Pilot
# 1     4000002     Paige      Chen   74                     Teacher
# 2     4000003    Sherri    Melton   34                 Firefighter
# 3     4000004  Gretchen      Hill   66  Computer hardware engineer
# 4     4000005     Karen   Puckett   74                      Lawyer
# ...       ...       ...       ...  ...                         ...
# 9994  4009995   Rebecca    Dennis   37                     Teacher
# 9995  4009996     Tonya  McIntosh   56      Engineering technician
# 9996  4009997       Ron    Grimes   36  Computer hardware engineer
# 9997  4009998    Tracey   Bullock   60  Computer hardware engineer
# 9998  4009999       Ray    Hewitt   64                   Carpenter
#
# [9999 rows x 5 columns]

# %% [markdown]
# # Read from Excel Sheet

# %%
excelDF = pd.read_excel(r"D:\Hp-EDrive\Edrive\nData\Superstore.xls", sheet_name="Orders")
excelDF
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2         3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3         4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4         5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ..      ...             ...        ...        ...             ...         ...
# 594     595  CA-2014-131450 2014-08-08 2014-08-15  Standard Class    LR-16915
# 595     596  CA-2014-131450 2014-08-08 2014-08-15  Standard Class    LR-16915
# 596     597  CA-2014-131450 2014-08-08 2014-08-15  Standard Class    LR-16915
# 597     598  CA-2014-131450 2014-08-08 2014-08-15  Standard Class    LR-16915
# 598     599  CA-2016-120180 2016-07-14 2016-07-16     First Class    TP-21130
#
# ...

# %% [markdown]
# # Read From json

# %%
jsonDF = pd.read_json(r"D:\Hp-EDrive\Edrive\nData\employee.json", encoding='latin')
jsonDF
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %% [markdown]
# # Read Image

# %%
import matplotlib.image as mpimg
imgArr = mpimg.imread(r"D:\Hp-EDrive\Edrive\nData\drcodd.png")

# %%
plt.imshow(imgArr)
plt.show()

# %% [markdown]
# # Read From Oracle DB

# %%
# pip install cx_oracle

# %%
import cx_Oracle
conn = cx_Oracle.connect("hr/hr@localhost/XEPDB1")
print(conn.version)
# Out:
# 18.4.0.0.0

# %%
deptDF = pd.read_sql("Select * from Departments", conn)
deptDF
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
empDF = pd.read_sql("Select * from Employees", conn)
empDF
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 102          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 104          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 106          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...
