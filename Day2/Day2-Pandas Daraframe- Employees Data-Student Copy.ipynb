# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
empdf = pd.read_csv("Empexport.csv",header=None)

# %%
empdf.columns = (['employee_id','first_name','last_name','job_id','salary',
                 'commission_pct','manager_id','department_id'])

# %%
empdf
# Out:
#      employee_id first_name last_name      job_id  salary commission_pct  \
# 0            100     Steven      King     AD_PRES   24000           Null
# 1            101      Neena   Kochhar       AD_VP   17000           Null
# 2            102        Lex   De Haan       AD_VP   17000           Null
# 3            103  Alexander    Hunold     IT_PROG    9000           Null
# 4            104      Bruce     Ernst     IT_PROG    6000           Null
# ..           ...        ...       ...         ...     ...            ...
# 102          202        Pat       Fay      MK_REP    6000           Null
# 103          203      Susan    Mavris      HR_REP    6500           Null
# 104          204    Hermann      Baer      PR_REP   10000           Null
# 105          205    Shelley   Higgins      AC_MGR   12008           Null
# 106          206    William     Gietz  AC_ACCOUNT    8300           Null
#
#     manager_id department_id
# 0         Null            90
# 1          100            90
# ...

# %% [markdown]
# # Take a Quick Glimpse of Data in Dataframe

# %%
empdf.head()         # First 5 rows from df

# %%
empdf.head(10)         # First 10 rows from df

# %%
empdf.tail()         # Last 5 rows from df

# %%
empdf.tail(10)         # Last 10 rows from df

# %%
len(empdf)            # number of rows in df

# %%
empdf.columns         # list of column labels

# %%
len(empdf.columns)     # number of columns in df

# %% [markdown]
# # Structural Details

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     107 non-null    int64
#  1   first_name      107 non-null    object
#  2   last_name       107 non-null    object
#  3   job_id          107 non-null    object
#  4   salary          107 non-null    int64
#  5   commission_pct  107 non-null    object
#  6   manager_id      107 non-null    object
#  7   department_id   107 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.8+ KB

# %%
empdf.describe()
# Out:
#        employee_id        salary
# count   107.000000    107.000000
# mean    153.000000   6461.831776
# std      31.032241   3909.579731
# min     100.000000   2100.000000
# 25%     126.500000   3100.000000
# 50%     153.000000   6200.000000
# 75%     179.500000   8900.000000
# max     206.000000  24000.000000

# %% [markdown]
# # Dataframe Slicing

# %%
"""
dataframe[rowSlice][colSlice]

rowSlice       start:stop:step

colSlice       [col_list]       [ [col1,col2,col3....] ]
"""

# %%
empdf[10:100:10]
# Out:
#     employee_id first_name last_name      job_id  salary commission_pct  \
# 10          110       John      Chen  FI_ACCOUNT    8200           Null
# 20          120    Matthew     Weiss      ST_MAN    8000           Null
# 30          130      Mozhe  Atkinson    ST_CLERK    2800           Null
# 40          140     Joshua     Patel    ST_CLERK    2500           Null
# 50          150      Peter    Tucker      SA_REP   10000            0.3
# 60          160     Louise     Doran      SA_REP    7500            0.3
# 70          170     Tayler       Fox      SA_REP    9600            0.2
# 80          180    Winston    Taylor    SH_CLERK    3200           Null
# 90          190    Timothy     Gates    SH_CLERK    2900           Null
#
#    manager_id department_id
# 10        108           100
# 20        100            50
# 30        121            50
# 40        123            50
# 50        145            80
# 60        146            80
# 70        148            80
# ...

# %%
empdf[::-1]
# Out:
#      employee_id first_name last_name      job_id  salary commission_pct  \
# 106          206    William     Gietz  AC_ACCOUNT    8300           Null
# 105          205    Shelley   Higgins      AC_MGR   12008           Null
# 104          204    Hermann      Baer      PR_REP   10000           Null
# 103          203      Susan    Mavris      HR_REP    6500           Null
# 102          202        Pat       Fay      MK_REP    6000           Null
# ..           ...        ...       ...         ...     ...            ...
# 4            104      Bruce     Ernst     IT_PROG    6000           Null
# 3            103  Alexander    Hunold     IT_PROG    9000           Null
# 2            102        Lex   De Haan       AD_VP   17000           Null
# 1            101      Neena   Kochhar       AD_VP   17000           Null
# 0            100     Steven      King     AD_PRES   24000           Null
#
#     manager_id department_id
# 106        205           110
# 105        101           110
# ...

# %%
empdf[0:-1]              # all rows except last
# Out:
#      employee_id first_name  last_name   job_id  salary commission_pct  \
# 0            100     Steven       King  AD_PRES   24000           Null
# 1            101      Neena    Kochhar    AD_VP   17000           Null
# 2            102        Lex    De Haan    AD_VP   17000           Null
# 3            103  Alexander     Hunold  IT_PROG    9000           Null
# 4            104      Bruce      Ernst  IT_PROG    6000           Null
# ..           ...        ...        ...      ...     ...            ...
# 101          201    Michael  Hartstein   MK_MAN   13000           Null
# 102          202        Pat        Fay   MK_REP    6000           Null
# 103          203      Susan     Mavris   HR_REP    6500           Null
# 104          204    Hermann       Baer   PR_REP   10000           Null
# 105          205    Shelley    Higgins   AC_MGR   12008           Null
#
#     manager_id department_id
# 0         Null            90
# 1          100            90
# ...

# %%
empdf[10:100:10][['employee_id','last_name','salary']]
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 20          120     Weiss    8000
# 30          130  Atkinson    2800
# 40          140     Patel    2500
# 50          150    Tucker   10000
# 60          160     Doran    7500
# 70          170       Fox    9600
# 80          180    Taylor    3200
# 90          190     Gates    2900

# %%
empdf[['employee_id','last_name','salary']]
# Out:
#      employee_id last_name  salary
# 0            100      King   24000
# 1            101   Kochhar   17000
# 2            102   De Haan   17000
# 3            103    Hunold    9000
# 4            104     Ernst    6000
# ..           ...       ...     ...
# 102          202       Fay    6000
# 103          203    Mavris    6500
# 104          204      Baer   10000
# 105          205   Higgins   12008
# 106          206     Gietz    8300
#
# [107 rows x 3 columns]

# %%
empdf[::][['employee_id','last_name','salary']]
# Out:
#      employee_id last_name  salary
# 0            100      King   24000
# 1            101   Kochhar   17000
# 2            102   De Haan   17000
# 3            103    Hunold    9000
# 4            104     Ernst    6000
# ..           ...       ...     ...
# 102          202       Fay    6000
# 103          203    Mavris    6500
# 104          204      Baer   10000
# 105          205   Higgins   12008
# 106          206     Gietz    8300
#
# [107 rows x 3 columns]

# %%
hDF = empdf.head()
hDF[0:2][['employee_id','last_name','salary']]
# Out:
#    employee_id last_name  salary
# 0          100      King   24000
# 1          101   Kochhar   17000

# %%
empdf.head()[0:2][['employee_id','last_name','salary']]
# Out:
#    employee_id last_name  salary
# 0          100      King   24000
# 1          101   Kochhar   17000

# %%
empdf.head()[['employee_id','last_name','salary']]
# Out:
#    employee_id last_name  salary
# 0          100      King   24000
# 1          101   Kochhar   17000
# 2          102   De Haan   17000
# 3          103    Hunold    9000
# 4          104     Ernst    6000

# %%
empdf.describe()[['salary']]
# Out:
#              salary
# count    107.000000
# mean    6461.831776
# std     3909.579731
# min     2100.000000
# 25%     3100.000000
# 50%     6200.000000
# 75%     8900.000000
# max    24000.000000

# %%
empdf.job_id   # allowed

# empdf.job id   # not allowed
# empdf.job$id   # not allowed
# Out:
# 0         AD_PRES
# 1           AD_VP
# 2           AD_VP
# 3         IT_PROG
# 4         IT_PROG
#           ...
# 102        MK_REP
# 103        HR_REP
# 104        PR_REP
# 105        AC_MGR
# 106    AC_ACCOUNT
# Name: job_id, Length: 107, dtype: object

# %%
empdf["job_id"]

# empdf["job id"]   # allowed
# empdf["job$id"]   # allowed
# Out:
# 0         AD_PRES
# 1           AD_VP
# 2           AD_VP
# 3         IT_PROG
# 4         IT_PROG
#           ...
# 102        MK_REP
# 103        HR_REP
# 104        PR_REP
# 105        AC_MGR
# 106    AC_ACCOUNT
# Name: job_id, Length: 107, dtype: object

# %%
empdf.job_id.unique()
# Out:
# array(['AD_PRES', 'AD_VP', 'IT_PROG', 'FI_MGR', 'FI_ACCOUNT', 'PU_MAN',
#        'PU_CLERK', 'ST_MAN', 'ST_CLERK', 'SA_MAN', 'SA_REP', 'SH_CLERK',
#        'AD_ASST', 'MK_MAN', 'MK_REP', 'HR_REP', 'PR_REP', 'AC_MGR',
#        'AC_ACCOUNT'], dtype=object)

# %%
empdf["job_id"].unique()
# Out:
# array(['AD_PRES', 'AD_VP', 'IT_PROG', 'FI_MGR', 'FI_ACCOUNT', 'PU_MAN',
#        'PU_CLERK', 'ST_MAN', 'ST_CLERK', 'SA_MAN', 'SA_REP', 'SH_CLERK',
#        'AD_ASST', 'MK_MAN', 'MK_REP', 'HR_REP', 'PR_REP', 'AC_MGR',
#        'AC_ACCOUNT'], dtype=object)

# %%
print(empdf.salary.mean())
print(empdf.salary.max())
# Out:
# 6461.8317757009345
# 24000

# %% [markdown]
# # Filtering the Dataframe

# %%
# display all employees with salary more than 10000

empdf[empdf.salary>10000][['employee_id','first_name','salary']]
# Out:
#      employee_id first_name  salary
# 0            100     Steven   24000
# 1            101      Neena   17000
# 2            102        Lex   17000
# 8            108      Nancy   12008
# 14           114        Den   11000
# 45           145       John   14000
# 46           146      Karen   13500
# 47           147    Alberto   12000
# 48           148     Gerald   11000
# 49           149      Eleni   10500
# 62           162      Clara   10500
# 68           168       Lisa   11500
# 74           174      Ellen   11000
# 101          201    Michael   13000
# 105          205    Shelley   12008

# %%
empdf[empdf.salary>10000]
# Out:
#      employee_id first_name  last_name   job_id  salary commission_pct  \
# 0            100     Steven       King  AD_PRES   24000           Null
# 1            101      Neena    Kochhar    AD_VP   17000           Null
# 2            102        Lex    De Haan    AD_VP   17000           Null
# 8            108      Nancy  Greenberg   FI_MGR   12008           Null
# 14           114        Den   Raphaely   PU_MAN   11000           Null
# 45           145       John    Russell   SA_MAN   14000            0.4
# 46           146      Karen   Partners   SA_MAN   13500            0.3
# 47           147    Alberto  Errazuriz   SA_MAN   12000            0.3
# 48           148     Gerald  Cambrault   SA_MAN   11000            0.3
# 49           149      Eleni    Zlotkey   SA_MAN   10500            0.2
# 62           162      Clara    Vishney   SA_REP   10500           0.25
# 68           168       Lisa       Ozer   SA_REP   11500           0.25
# ...

# %%
"""
and    => &   or  => |
"""

# %%
empdf[ (empdf.salary < 5000) & (empdf.department_id  == '50')]
# Out:
#     employee_id first_name    last_name    job_id  salary commission_pct  \
# 25          125      Julia        Nayer  ST_CLERK    3200           Null
# 26          126      Irene  Mikkilineni  ST_CLERK    2700           Null
# 27          127      James       Landry  ST_CLERK    2400           Null
# 28          128     Steven       Markle  ST_CLERK    2200           Null
# 29          129      Laura       Bissot  ST_CLERK    3300           Null
# 30          130      Mozhe     Atkinson  ST_CLERK    2800           Null
# 31          131      James       Marlow  ST_CLERK    2500           Null
# 32          132         TJ        Olson  ST_CLERK    2100           Null
# 33          133      Jason       Mallin  ST_CLERK    3300           Null
# 34          134    Michael       Rogers  ST_CLERK    2900           Null
# 35          135         Ki          Gee  ST_CLERK    2400           Null
# 36          136      Hazel   Philtanker  ST_CLERK    2200           Null
# ...

# %%
condition1 = (empdf.manager_id == '100')
condition2 = (empdf.job_id == 'PU_CLERK')

empdf[condition1 | condition2]
# Out:
#      employee_id first_name   last_name    job_id  salary commission_pct  \
# 1            101      Neena     Kochhar     AD_VP   17000           Null
# 2            102        Lex     De Haan     AD_VP   17000           Null
# 14           114        Den    Raphaely    PU_MAN   11000           Null
# 15           115  Alexander        Khoo  PU_CLERK    3100           Null
# 16           116     Shelli       Baida  PU_CLERK    2900           Null
# 17           117      Sigal      Tobias  PU_CLERK    2800           Null
# 18           118        Guy      Himuro  PU_CLERK    2600           Null
# 19           119      Karen  Colmenares  PU_CLERK    2500           Null
# 20           120    Matthew       Weiss    ST_MAN    8000           Null
# 21           121       Adam       Fripp    ST_MAN    8200           Null
# 22           122      Payam    Kaufling    ST_MAN    7900           Null
# 23           123     Shanta     Vollman    ST_MAN    6500           Null
# ...

# %%
# display employees with job_id SA_REP, PU_CLERK, IT_PROG, MK_MAN

empdf[empdf.job_id.isin( ['SA_REP', 'PU_CLERK', 'IT_PROG', 'MK_MAN'] )]
# Out:
#      employee_id   first_name   last_name    job_id  salary commission_pct  \
# 3            103    Alexander      Hunold   IT_PROG    9000           Null
# 4            104        Bruce       Ernst   IT_PROG    6000           Null
# 5            105        David      Austin   IT_PROG    4800           Null
# 6            106        Valli   Pataballa   IT_PROG    4800           Null
# 7            107        Diana     Lorentz   IT_PROG    4200           Null
# 15           115    Alexander        Khoo  PU_CLERK    3100           Null
# 16           116       Shelli       Baida  PU_CLERK    2900           Null
# 17           117        Sigal      Tobias  PU_CLERK    2800           Null
# 18           118          Guy      Himuro  PU_CLERK    2600           Null
# 19           119        Karen  Colmenares  PU_CLERK    2500           Null
# 50           150        Peter      Tucker    SA_REP   10000            0.3
# ...

# %%
empdf[empdf.job_id.str.contains("CLERK")]
# Out:
#     employee_id first_name    last_name    job_id  salary commission_pct  \
# 15          115  Alexander         Khoo  PU_CLERK    3100           Null
# 16          116     Shelli        Baida  PU_CLERK    2900           Null
# 17          117      Sigal       Tobias  PU_CLERK    2800           Null
# 18          118        Guy       Himuro  PU_CLERK    2600           Null
# 19          119      Karen   Colmenares  PU_CLERK    2500           Null
# 25          125      Julia        Nayer  ST_CLERK    3200           Null
# 26          126      Irene  Mikkilineni  ST_CLERK    2700           Null
# 27          127      James       Landry  ST_CLERK    2400           Null
# 28          128     Steven       Markle  ST_CLERK    2200           Null
# 29          129      Laura       Bissot  ST_CLERK    3300           Null
# 30          130      Mozhe     Atkinson  ST_CLERK    2800           Null
# 31          131      James       Marlow  ST_CLERK    2500           Null
# ...

# %%
empdf[empdf.last_name.str.startswith("A")]
# Out:
#     employee_id first_name last_name    job_id  salary commission_pct  \
# 5           105      David    Austin   IT_PROG    4800           Null
# 30          130      Mozhe  Atkinson  ST_CLERK    2800           Null
# 66          166     Sundar      Ande    SA_REP    6400            0.1
# 74          174      Ellen      Abel    SA_REP   11000            0.3
#
#    manager_id department_id
# 5         103            60
# 30        121            50
# 66        147            80
# 74        149            80

# %%
empdf[empdf.department_id=='50'].head()
# Out:
#     employee_id first_name last_name  job_id  salary commission_pct  \
# 20          120    Matthew     Weiss  ST_MAN    8000           Null
# 21          121       Adam     Fripp  ST_MAN    8200           Null
# 22          122      Payam  Kaufling  ST_MAN    7900           Null
# 23          123     Shanta   Vollman  ST_MAN    6500           Null
# 24          124      Kevin   Mourgos  ST_MAN    5800           Null
#
#    manager_id department_id
# 20        100            50
# 21        100            50
# 22        100            50
# 23        100            50
# 24        100            50

# %%
empdf[empdf.department_id=='50'].describe()[['salary']]
# Out:
#             salary
# count    45.000000
# mean   3475.555556
# std    1488.005919
# min    2100.000000
# 25%    2600.000000
# 50%    3100.000000
# 75%    3600.000000
# max    8200.000000

# %%
# empdf[empdf.department_id=='50'].describe()['salary','employee_id'] # mulitple col [] error
# Out:
#             salary  employee_id
# count    45.000000    45.000000
# mean   3475.555556   157.555556
# std    1488.005919    29.657557
# min    2100.000000   120.000000
# 25%    2600.000000   131.000000
# 50%    3100.000000   142.000000
# 75%    3600.000000   188.000000
# max    8200.000000   199.000000

# %%
empdf[empdf.department_id=='50'].describe()['salary']   # single col [] => returns series
# Out:
# count      45.000000
# mean     3475.555556
# std      1488.005919
# min      2100.000000
# 25%      2600.000000
# 50%      3100.000000
# 75%      3600.000000
# max      8200.000000
# Name: salary, dtype: float64

# %%
empdf[empdf.department_id=='50'].describe()[['salary','employee_id']]  # [[]] must

# %%
empdf[empdf.department_id=='50'].describe()[['salary']] # single col [[]] => returns dataframe
# Out:
#             salary
# count    45.000000
# mean   3475.555556
# std    1488.005919
# min    2100.000000
# 25%    2600.000000
# 50%    3100.000000
# 75%    3600.000000
# max    8200.000000

# %% [markdown]
# # Sorting of DF

# %%
empdf.sort_values(by='salary',ascending=False)
# Out:
#     employee_id first_name   last_name    job_id  salary commission_pct  \
# 0           100     Steven        King   AD_PRES   24000           Null
# 2           102        Lex     De Haan     AD_VP   17000           Null
# 1           101      Neena     Kochhar     AD_VP   17000           Null
# 45          145       John     Russell    SA_MAN   14000            0.4
# 46          146      Karen    Partners    SA_MAN   13500            0.3
# ..          ...        ...         ...       ...     ...            ...
# 27          127      James      Landry  ST_CLERK    2400           Null
# 35          135         Ki         Gee  ST_CLERK    2400           Null
# 28          128     Steven      Markle  ST_CLERK    2200           Null
# 36          136      Hazel  Philtanker  ST_CLERK    2200           Null
# 32          132         TJ       Olson  ST_CLERK    2100           Null
#
#    manager_id department_id
# 0        Null            90
# 2         100            90
# ...

# %% [markdown]
# # Grouping of DF

# %%
gResult = empdf[empdf.department_id.isin(['50','100','60','70'])].groupby('department_id')[['salary','employee_id']].count()
gResult
# Out:
#                salary  employee_id
# department_id
# 100                 6            6
# 50                 45           45
# 60                  5            5
# 70                  1            1

# %%
gResult = empdf.groupby('department_id')[['salary','employee_id']].count()
gResult
# Out:
#                salary  employee_id
# department_id
# 10                  1            1
# 100                 6            6
# 110                 2            2
# 20                  2            2
# 30                  6            6
# 40                  1            1
# 50                 45           45
# 60                  5            5
# 70                  1            1
# 80                 34           34
# 90                  3            3
# Null                1            1

# %%
gResult = empdf.groupby('department_id')[['salary']].sum()
gResult
# Out:
#                salary
# department_id
# 10               4400
# 100             51608
# 110             20308
# 20              19000
# 30              24900
# 40               6500
# 50             156400
# 60              28800
# 70              10000
# 80             304500
# 90              58000
# Null             7000

# %%
gResult = empdf.groupby('department_id')['salary'].sum()
gResult
# Out:
# department_id
# 10        4400
# 100      51608
# 110      20308
# 20       19000
# 30       24900
# 40        6500
# 50      156400
# 60       28800
# 70       10000
# 80      304500
# 90       58000
# Null      7000
# Name: salary, dtype: int64

# %%
gResult = empdf.groupby('job_id')['employee_id'].count()
gResult.plot.bar()
plt.show()

# %% [markdown]
# # Type Casting Columns

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     107 non-null    int64
#  1   first_name      107 non-null    object
#  2   last_name       107 non-null    object
#  3   job_id          107 non-null    object
#  4   salary          107 non-null    int64
#  5   commission_pct  107 non-null    object
#  6   manager_id      107 non-null    object
#  7   department_id   107 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.8+ KB

# %%
def convertInt(x):
    if x == 'Null':
        return 0
    else:
        return int(x)

# %%
def convertFloat(x):
    if x == 'Null':
        return 0.0
    else:
        return float(x)

# %%
empdf.department_id = empdf.department_id.apply(convertInt)
empdf.manager_id = empdf.manager_id.apply(convertInt)
empdf.commission_pct = empdf.commission_pct.apply(convertFloat)

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     107 non-null    int64
#  1   first_name      107 non-null    object
#  2   last_name       107 non-null    object
#  3   job_id          107 non-null    object
#  4   salary          107 non-null    int64
#  5   commission_pct  107 non-null    float64
#  6   manager_id      107 non-null    int64
#  7   department_id   107 non-null    int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 6.8+ KB

# %%
empdf.describe()
# Out:
#        employee_id        salary  commission_pct  manager_id  department_id
# count   107.000000    107.000000      107.000000  107.000000     107.000000
# mean    153.000000   6461.831776        0.072897  123.598131      62.616822
# std      31.032241   3909.579731        0.115595   23.543561      21.689770
# min     100.000000   2100.000000        0.000000    0.000000       0.000000
# 25%     126.500000   3100.000000        0.000000  108.000000      50.000000
# 50%     153.000000   6200.000000        0.000000  122.000000      50.000000
# 75%     179.500000   8900.000000        0.150000  145.000000      80.000000
# max     206.000000  24000.000000        0.400000  205.000000     110.000000

# %%
"""
column    [10 20 30 Null 40 50]
df col    ['10' '20' '30' 'Null' '40' '50']   # used userdefined logic for type casting

Read from data.txt 
column    ['10' '20' '30' '60' '40' '50']
df col    ['10' '20' '30' '60' '40' '50']

df.col = df.col.astype('int')

"""

# %% [markdown]
# # Dataframe Manipulations

# %%
empdfCp = empdf[10:100:10][['employee_id','last_name','salary']]

# %%
empdfCp
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 20          120     Weiss    8000
# 30          130  Atkinson    2800
# 40          140     Patel    2500
# 50          150    Tucker   10000
# 60          160     Doran    7500
# 70          170       Fox    9600
# 80          180    Taylor    3200
# 90          190     Gates    2900

# %%
empdfCp['annualSal'] = empdfCp.salary*12

# %%
empdfCp
# Out:
#     employee_id last_name  salary  annualSal
# 10          110      Chen    8200      98400
# 20          120     Weiss    8000      96000
# 30          130  Atkinson    2800      33600
# 40          140     Patel    2500      30000
# 50          150    Tucker   10000     120000
# 60          160     Doran    7500      90000
# 70          170       Fox    9600     115200
# 80          180    Taylor    3200      38400
# 90          190     Gates    2900      34800

# %%
empdfCp.drop('annualSal',axis=1,inplace=True)

# %%
empdfCp
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 20          120     Weiss    8000
# 30          130  Atkinson    2800
# 40          140     Patel    2500
# 50          150    Tucker   10000
# 60          160     Doran    7500
# 70          170       Fox    9600
# 80          180    Taylor    3200
# 90          190     Gates    2900

# %%
empdfCp.drop([50,70,90],inplace=True)   # Drop rows default axis=0

# %%
empdfCp
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 20          120     Weiss    8000
# 30          130  Atkinson    2800
# 40          140     Patel    2500
# 60          160     Doran    7500
# 80          180    Taylor    3200

# %%
empdf
# Out:
#      employee_id first_name last_name      job_id  salary  commission_pct  \
# 0            100     Steven      King     AD_PRES   24000             0.0
# 1            101      Neena   Kochhar       AD_VP   17000             0.0
# 2            102        Lex   De Haan       AD_VP   17000             0.0
# 3            103  Alexander    Hunold     IT_PROG    9000             0.0
# 4            104      Bruce     Ernst     IT_PROG    6000             0.0
# ..           ...        ...       ...         ...     ...             ...
# 102          202        Pat       Fay      MK_REP    6000             0.0
# 103          203      Susan    Mavris      HR_REP    6500             0.0
# 104          204    Hermann      Baer      PR_REP   10000             0.0
# 105          205    Shelley   Higgins      AC_MGR   12008             0.0
# 106          206    William     Gietz  AC_ACCOUNT    8300             0.0
#
#      manager_id  department_id
# 0             0             90
# ...

# %% [markdown]
# # Access DF with index
#
# ### iloc[rowIndex, colIndex]
#
# ### iloc[rowIndex, colIndex].values  returns numpy array

# %%
"""
if colIndex is mentioned using : or [] then we get a 2d numpy array
if colIndex is mentioned as a single integer then we get a 1d numpy array

"""

# %%
empdf.iloc[0:10,0:5].values    # 2d numpy array   10 rows 5 columns
# Out:
# array([[100, 'Steven', 'King', 'AD_PRES', 24000],
#        [101, 'Neena', 'Kochhar', 'AD_VP', 17000],
#        [102, 'Lex', 'De Haan', 'AD_VP', 17000],
#        [103, 'Alexander', 'Hunold', 'IT_PROG', 9000],
#        [104, 'Bruce', 'Ernst', 'IT_PROG', 6000],
#        [105, 'David', 'Austin', 'IT_PROG', 4800],
#        [106, 'Valli', 'Pataballa', 'IT_PROG', 4800],
#        [107, 'Diana', 'Lorentz', 'IT_PROG', 4200],
#        [108, 'Nancy', 'Greenberg', 'FI_MGR', 12008],
#        [109, 'Daniel', 'Faviet', 'FI_ACCOUNT', 9000]], dtype=object)

# %%
empdf.iloc[0:10,[2,4,6,7]].values   # 2d numpy array  10 rows 4 column
# Out:
# array([['King', 24000, 0, 90],
#        ['Kochhar', 17000, 100, 90],
#        ['De Haan', 17000, 100, 90],
#        ['Hunold', 9000, 102, 60],
#        ['Ernst', 6000, 103, 60],
#        ['Austin', 4800, 103, 60],
#        ['Pataballa', 4800, 103, 60],
#        ['Lorentz', 4200, 103, 60],
#        ['Greenberg', 12008, 101, 100],
#        ['Faviet', 9000, 108, 100]], dtype=object)

# %%
empdf.iloc[0:10,[4]].values   # 2d numpy array   10 rows  1 column
# Out:
# array([[24000],
#        [17000],
#        [17000],
#        [ 9000],
#        [ 6000],
#        [ 4800],
#        [ 4800],
#        [ 4200],
#        [12008],
#        [ 9000]], dtype=int64)

# %%
empdf.iloc[0:10, 0:-1].values   # 2d numpy array  all rows except last
# Out:
# array([[100, 'Steven', 'King', 'AD_PRES', 24000, 0.0, 0],
#        [101, 'Neena', 'Kochhar', 'AD_VP', 17000, 0.0, 100],
#        [102, 'Lex', 'De Haan', 'AD_VP', 17000, 0.0, 100],
#        [103, 'Alexander', 'Hunold', 'IT_PROG', 9000, 0.0, 102],
#        [104, 'Bruce', 'Ernst', 'IT_PROG', 6000, 0.0, 103],
#        [105, 'David', 'Austin', 'IT_PROG', 4800, 0.0, 103],
#        [106, 'Valli', 'Pataballa', 'IT_PROG', 4800, 0.0, 103],
#        [107, 'Diana', 'Lorentz', 'IT_PROG', 4200, 0.0, 103],
#        [108, 'Nancy', 'Greenberg', 'FI_MGR', 12008, 0.0, 101],
#        [109, 'Daniel', 'Faviet', 'FI_ACCOUNT', 9000, 0.0, 108]],
#       dtype=object)

# %%
empdf.iloc[0:10, 7].values    # 1d numpy array with 10 values
# Out:
# array([ 90,  90,  90,  60,  60,  60,  60,  60, 100, 100], dtype=int64)

# %% [markdown]
# # Save the DF output into a File

# %%
empdf.to_csv("CleanedDF.csv", header=True,index=True)

# %%
empdf.to_csv("CleanedDF2.csv", header=True,index=False)

# %%
empdf.describe().to_csv("EmpReport.csv", header=True,index=True)

# %% [markdown]
# # Departmentwise Salary Analysis

# %%
DFpie = pd.DataFrame(empdf.groupby('department_id')['salary'].sum())
DFpie= DFpie.reset_index()
DFpie
# Out:
#     department_id  salary
# 0               0    7000
# 1              10    4400
# 2              20   19000
# 3              30   24900
# 4              40    6500
# 5              50  156400
# 6              60   28800
# 7              70   10000
# 8              80  304500
# 9              90   58000
# 10            100   51608
# 11            110   20308

# %%
plt.pie(DFpie[DFpie.department_id<50].salary,
       labels=DFpie[DFpie.department_id<50].department_id,
       autopct='%1.1f%%',
       startangle=90,radius=1.4)
plt.legend(bbox_to_anchor=(1,1))
plt.axis('image')
plt.show()
